# %% [markdown]
# # imports

# %%
import sys
import os
sys.path.append('..')

# %%
import pandas as pd
import spotifyAPI as spot
from datetime import datetime

# %% [markdown]
# # read in charts.csv

# %%
charts = pd.read_csv('../data/charts.csv')

# %%
charts.head()
# Out:
#    Unnamed: 0        date  rank           song                         artist  \
# 0           0  2021-11-06     1     Easy On Me                          Adele
# 1           1  2021-11-06     2           Stay  The Kid LAROI & Justin Bieber
# 2           2  2021-11-06     3  Industry Baby        Lil Nas X & Jack Harlow
# 3           3  2021-11-06     4     Fancy Like                   Walker Hayes
# 4           4  2021-11-06     5     Bad Habits                     Ed Sheeran
#
#    last-week  peak-rank  weeks-on-board  release_year
# 0        1.0          1               3          2021
# 1        2.0          1              16          2021
# 2        3.0          1              14          2021
# 3        4.0          3              19          2021
# 4        5.0          2              18          2021

# %% [markdown]
# **filter down to target year**

# %%
charts_2019 = charts.copy().loc[charts.release_year == 2019]

# %%
charts_2019.reset_index(inplace=True)

# %%
charts_2019.drop(columns = ['index'], inplace=True)

# %% [markdown]
# **filter down to just top 100**

# %%
charts_2019 = charts_2019.loc[0:99]

# %%
for index, row in charts_2019.iterrows():
    song_response = spot.search(search_term = row.song, music_type='track', limit = 2)

    try:

        id = song_response.get('tracks').get('items')[0].get('id')

        track_name = song_response.get('tracks').get('items')[0].get('name')

        if track_name != row.song:
            print('maybe does not match')

        charts_2019.loc[index, 'track_id'] = id
        print(f'PROGRESS: {index}/{len(charts_2019)}')
    
    except:
        print('NO MATCHES')
        charts_2019.loc[index, 'track_id'] = 'noid'
        continue
# Out:
# https://api.spotify.com/v1/search?q=track:All%20I%20Want%20For%20Christmas%20Is%20You&type=track&limit=2
# maybe does not match
# PROGRESS: 0/100
# C:\Users\theoc\AppData\Local\Temp\ipykernel_5928\3630190943.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   charts_2019.loc[index, 'track_id'] = id
# https://api.spotify.com/v1/search?q=track:Rockin'%20Around%20The%20Christmas%20Tree&type=track&limit=2
# PROGRESS: 1/100
# https://api.spotify.com/v1/search?q=track:Circles&type=track&limit=2
# PROGRESS: 2/100
# https://api.spotify.com/v1/search?q=track:Roxanne&type=track&limit=2
# maybe does not match
# PROGRESS: 3/100
# https://api.spotify.com/v1/search?q=track:Futsal%20Shuffle%202020&type=track&limit=2
# PROGRESS: 4/100
# https://api.spotify.com/v1/search?q=track:A%20Holly%20Jolly%20Christmas&type=track&limit=2
# PROGRESS: 5/100
# https://api.spotify.com/v1/search?q=track:Memories&type=track&limit=2
# maybe does not match
# PROGRESS: 6/100
# https://api.spotify.com/v1/search?q=track:Someone%20You%20Loved&type=track&limit=2
# PROGRESS: 7/100
# https://api.spotify.com/v1/search?q=track:Jingle%20Bell%20Rock&type=track&limit=2
# PROGRESS: 8/100
# https://api.spotify.com/v1/search?q=track:Good%20As%20Hell&type=track&limit=2
# maybe does not match
# PROGRESS: 9/100
# https://api.spotify.com/v1/search?q=track:Dance%20Monkey&type=track&limit=2
# PROGRESS: 10/100
# https://api.spotify.com/v1/search?q=track:Lose%20You%20To%20Love%20Me&type=track&limit=2
# PROGRESS: 11/100
# https://api.spotify.com/v1/search?q=track:10,000%20Hours&type=track&limit=2
# maybe does not match
# PROGRESS: 12/100
# https://api.spotify.com/v1/search?q=track:Ballin'&type=track&limit=2
# maybe does not match
# PROGRESS: 13/100
# https://api.spotify.com/v1/search?q=track:It's%20The%20Most%20Wonderful%20Time%20Of%20The%20Year&type=track&limit=2
# maybe does not match
# PROGRESS: 14/100
# https://api.spotify.com/v1/search?q=track:BOP&type=track&limit=2
# PROGRESS: 15/100
# https://api.spotify.com/v1/search?q=track:Last%20Christmas&type=track&limit=2
# PROGRESS: 16/100
# https://api.spotify.com/v1/search?q=track:The%20Box&type=track&limit=2
# PROGRESS: 17/100
# https://api.spotify.com/v1/search?q=track:Bandit&type=track&limit=2
# maybe does not match
# PROGRESS: 18/100
# https://api.spotify.com/v1/search?q=track:No%20Guidance&type=track&limit=2
# maybe does not match
# PROGRESS: 19/100
# https://api.spotify.com/v1/search?q=track:Senorita&type=track&limit=2
# maybe does not match
# PROGRESS: 20/100
# https://api.spotify.com/v1/search?q=track:Lucid%20Dreams&type=track&limit=2
# PROGRESS: 21/100
# https://api.spotify.com/v1/search?q=track:Feliz%20Navidad&type=track&limit=2
# PROGRESS: 22/100
# https://api.spotify.com/v1/search?q=track:Adore%20You&type=track&limit=2
# PROGRESS: 23/100
# https://api.spotify.com/v1/search?q=track:Bad%20Guy&type=track&limit=2
# maybe does not match
# PROGRESS: 24/100
# https://api.spotify.com/v1/search?q=track:Heartless&type=track&limit=2
# PROGRESS: 25/100
# https://api.spotify.com/v1/search?q=track:HIGHEST%20IN%20THE%20ROOM&type=track&limit=2
# PROGRESS: 26/100
# https://api.spotify.com/v1/search?q=track:Let%20It%20Snow,%20Let%20It%20Snow,%20Let%20It%20Snow&type=track&limit=2
# maybe does not match
# PROGRESS: 27/100
# https://api.spotify.com/v1/search?q=track:Panini&type=track&limit=2
# PROGRESS: 28/100
# https://api.spotify.com/v1/search?q=track:The%20Christmas%20Song%20(Merry%20Christmas%20To%20You)&type=track&limit=2
# PROGRESS: 29/100
# https://api.spotify.com/v1/search?q=track:Hot&type=track&limit=2
# maybe does not match
# PROGRESS: 30/100
# https://api.spotify.com/v1/search?q=track:Truth%20Hurts&type=track&limit=2
# PROGRESS: 31/100
# https://api.spotify.com/v1/search?q=track:Trampoline&type=track&limit=2
# PROGRESS: 32/100
# https://api.spotify.com/v1/search?q=track:Everything%20I%20Wanted&type=track&limit=2
# maybe does not match
# PROGRESS: 33/100
# https://api.spotify.com/v1/search?q=track:Woah&type=track&limit=2
# PROGRESS: 34/100
# https://api.spotify.com/v1/search?q=track:Rudolph%20The%20Red-Nosed%20Reindeer&type=track&limit=2
# PROGRESS: 35/100
# https://api.spotify.com/v1/search?q=track:Sleigh%20Ride&type=track&limit=2
# PROGRESS: 36/100
# https://api.spotify.com/v1/search?q=track:Falling&type=track&limit=2
# PROGRESS: 37/100
# https://api.spotify.com/v1/search?q=track:Ran$om&type=track&limit=2
# maybe does not match
# PROGRESS: 38/100
# https://api.spotify.com/v1/search?q=track:Happy%20Holiday%20/%20The%20Holiday%20Season&type=track&limit=2
# PROGRESS: 39/100
# https://api.spotify.com/v1/search?q=track:Old%20Town%20Road&type=track&limit=2
# maybe does not match
# PROGRESS: 40/100
# https://api.spotify.com/v1/search?q=track:Don't%20Start%20Now&type=track&limit=2
# maybe does not match
# PROGRESS: 41/100
# https://api.spotify.com/v1/search?q=track:No%20Idea&type=track&limit=2
# PROGRESS: 42/100
# https://api.spotify.com/v1/search?q=track:One%20Man%20Band&type=track&limit=2
# PROGRESS: 43/100
# https://api.spotify.com/v1/search?q=track:Only%20Human&type=track&limit=2
# PROGRESS: 44/100
# https://api.spotify.com/v1/search?q=track:On%20Chill&type=track&limit=2
# maybe does not match
# PROGRESS: 45/100
# https://api.spotify.com/v1/search?q=track:Here%20Comes%20Santa%20Claus%20(Right%20Down%20Santa%20Claus%20Lane)&type=track&limit=2
# PROGRESS: 46/100
# https://api.spotify.com/v1/search?q=track:Lover&type=track&limit=2
# maybe does not match
# PROGRESS: 47/100
# https://api.spotify.com/v1/search?q=track:Even%20Though%20I'm%20Leaving&type=track&limit=2
# PROGRESS: 48/100
# https://api.spotify.com/v1/search?q=track:It's%20Beginning%20To%20Look%20A%20Lot%20Like%20Christmas&type=track&limit=2
# maybe does not match
# PROGRESS: 49/100
# https://api.spotify.com/v1/search?q=track:Hot%20Girl%20Bummer&type=track&limit=2
# maybe does not match
# PROGRESS: 50/100
# https://api.spotify.com/v1/search?q=track:Graveyard&type=track&limit=2
# PROGRESS: 51/100
# https://api.spotify.com/v1/search?q=track:Like%20It's%20Christmas&type=track&limit=2
# maybe does not match
# PROGRESS: 52/100
# https://api.spotify.com/v1/search?q=track:Watermelon%20Sugar&type=track&limit=2
# PROGRESS: 53/100
# https://api.spotify.com/v1/search?q=track:The%20Bones&type=track&limit=2
# PROGRESS: 54/100
# https://api.spotify.com/v1/search?q=track:Playing%20Games&type=track&limit=2
# maybe does not match
# PROGRESS: 55/100
# https://api.spotify.com/v1/search?q=track:Juicy&type=track&limit=2
# maybe does not match
# PROGRESS: 56/100
# https://api.spotify.com/v1/search?q=track:Suicidal&type=track&limit=2
# PROGRESS: 57/100
# https://api.spotify.com/v1/search?q=track:Heat&type=track&limit=2
# maybe does not match
# PROGRESS: 58/100
# https://api.spotify.com/v1/search?q=track:VIBEZ&type=track&limit=2
# PROGRESS: 59/100
# https://api.spotify.com/v1/search?q=track:My%20Oh%20My&type=track&limit=2
# maybe does not match
# PROGRESS: 60/100
# https://api.spotify.com/v1/search?q=track:Falling&type=track&limit=2
# PROGRESS: 61/100
# https://api.spotify.com/v1/search?q=track:Blinding%20Lights&type=track&limit=2
# PROGRESS: 62/100
# https://api.spotify.com/v1/search?q=track:Lights%20Up&type=track&limit=2
# PROGRESS: 63/100
# https://api.spotify.com/v1/search?q=track:Into%20The%20Unknown&type=track&limit=2
# maybe does not match
# PROGRESS: 64/100
# https://api.spotify.com/v1/search?q=track:Ridin'%20Roads&type=track&limit=2
# maybe does not match
# PROGRESS: 65/100
# https://api.spotify.com/v1/search?q=track:Dirty%20Iyanna&type=track&limit=2
# PROGRESS: 66/100
# https://api.spotify.com/v1/search?q=track:What%20If%20I%20Never%20Get%20Over%20You&type=track&limit=2
# PROGRESS: 67/100
# https://api.spotify.com/v1/search?q=track:Start%20Wit%20Me&type=track&limit=2
# maybe does not match
# PROGRESS: 68/100
# https://api.spotify.com/v1/search?q=track:Heart%20On%20Ice&type=track&limit=2
# PROGRESS: 69/100
# https://api.spotify.com/v1/search?q=track:Camelot&type=track&limit=2
# PROGRESS: 70/100
# https://api.spotify.com/v1/search?q=track:Heartache%20Medication&type=track&limit=2
# PROGRESS: 71/100
# https://api.spotify.com/v1/search?q=track:Remember%20You%20Young&type=track&limit=2
# PROGRESS: 72/100
# https://api.spotify.com/v1/search?q=track:Death&type=track&limit=2
# maybe does not match
# PROGRESS: 73/100
# https://api.spotify.com/v1/search?q=track:Hate%20Me&type=track&limit=2
# maybe does not match
# PROGRESS: 74/100
# https://api.spotify.com/v1/search?q=track:Take%20What%20You%20Want&type=track&limit=2
# maybe does not match
# PROGRESS: 75/100
# https://api.spotify.com/v1/search?q=track:Leave%20Em%20Alone&type=track&limit=2
# maybe does not match
# PROGRESS: 76/100
# https://api.spotify.com/v1/search?q=track:Let%20Me%20Know%20(I%20Wonder%20Why%20Freestyle)&type=track&limit=2
# PROGRESS: 77/100
# https://api.spotify.com/v1/search?q=track:Nobody%20But%20You&type=track&limit=2
# PROGRESS: 78/100
# https://api.spotify.com/v1/search?q=track:Tip%20Toe&type=track&limit=2
# PROGRESS: 79/100
# https://api.spotify.com/v1/search?q=track:Kinfolks&type=track&limit=2
# PROGRESS: 80/100
# https://api.spotify.com/v1/search?q=track:Nice%20To%20Meet%20Ya&type=track&limit=2
# PROGRESS: 81/100
# https://api.spotify.com/v1/search?q=track:Famous%20Hoes&type=track&limit=2
# PROGRESS: 82/100
# https://api.spotify.com/v1/search?q=track:Cherry&type=track&limit=2
# maybe does not match
# PROGRESS: 83/100
# https://api.spotify.com/v1/search?q=track:Vete&type=track&limit=2
# PROGRESS: 84/100
# https://api.spotify.com/v1/search?q=track:Golden&type=track&limit=2
# maybe does not match
# PROGRESS: 85/100
# https://api.spotify.com/v1/search?q=track:Prayed%20For%20You&type=track&limit=2
# PROGRESS: 86/100
# https://api.spotify.com/v1/search?q=track:Slow%20Dancing%20In%20The%20Dark&type=track&limit=2
# maybe does not match
# PROGRESS: 87/100
# https://api.spotify.com/v1/search?q=track:RITMO%20(Bad%20Boys%20For%20Life)&type=track&limit=2
# PROGRESS: 88/100
# https://api.spotify.com/v1/search?q=track:Peta&type=track&limit=2
# PROGRESS: 89/100
# https://api.spotify.com/v1/search?q=track:223's&type=track&limit=2
# maybe does not match
# PROGRESS: 90/100
# https://api.spotify.com/v1/search?q=track:BEST%20ON%20EARTH&type=track&limit=2
# maybe does not match
# PROGRESS: 91/100
# https://api.spotify.com/v1/search?q=track:Baby%20Sitter&type=track&limit=2
# maybe does not match
# PROGRESS: 92/100
# https://api.spotify.com/v1/search?q=track:Candy&type=track&limit=2
# maybe does not match
# PROGRESS: 93/100
# https://api.spotify.com/v1/search?q=track:Yellow%20Hearts&type=track&limit=2
# PROGRESS: 94/100
# https://api.spotify.com/v1/search?q=track:Homesick&type=track&limit=2
# PROGRESS: 95/100
# https://api.spotify.com/v1/search?q=track:Easy&type=track&limit=2
# maybe does not match
# PROGRESS: 96/100
# https://api.spotify.com/v1/search?q=track:Enemies&type=track&limit=2
# maybe does not match
# PROGRESS: 97/100
# https://api.spotify.com/v1/search?q=track:She&type=track&limit=2
# maybe does not match
# PROGRESS: 98/100
# https://api.spotify.com/v1/search?q=track:6%20Kiss&type=track&limit=2
# maybe does not match
# PROGRESS: 99/100

# %%
charts_2019.to_csv('../data/charts_2019.csv')

# %%
charts_2019
# Out:
#     Unnamed: 0        date  rank                               song  \
# 0         9700  2019-12-28     1    All I Want For Christmas Is You
# 1         9701  2019-12-28     2  Rockin' Around The Christmas Tree
# 2         9702  2019-12-28     3                            Circles
# 3         9703  2019-12-28     4                            Roxanne
# 4         9704  2019-12-28     5                Futsal Shuffle 2020
# ..         ...         ...   ...                                ...
# 95        9795  2019-12-28    96                           Homesick
# 96        9796  2019-12-28    97                               Easy
# 97        9797  2019-12-28    98                            Enemies
# 98        9798  2019-12-28    99                                She
# 99        9799  2019-12-28   100                             6 Kiss
#
#                                            artist  last-week  peak-rank  \
# 0                                    Mariah Carey        1.0          1
# 1                                      Brenda Lee        3.0          2
# 2                                     Post Malone        2.0          1
# 3                                  Arizona Zervas        6.0          4
# 4                                    Lil Uzi Vert        NaN          5
# ..                                            ...        ...        ...
# 95                                     Kane Brown       90.0         88
# 96                DaniLeigh Featuring Chris Brown       89.0         88
# 97                   Post Malone Featuring DaBaby       83.0         16
# 98                                   Harry Styles        NaN         99
# 99  Trippie Redd Featuring Juice WRLD & YNW Melly       78.0         60
#
#     weeks-on-board  release_year                track_id
# 0               36          2019  0bYg9bo50gSsH3LtXe2SQn
# 1               31          2019  2EjXfH91m7f8HiJN1yQg97
# 2               16          2019  21jGcNKet2qwijlDFuPiPb
# 3                7          2019  696DnlkuDOXcMAnKlTgXXK
# 4                1          2019  2Ec33AVlkTTq8BHFgBTdQs
# ..             ...           ...                     ...
# 95               5          2019  0jkzxxDG8z3Y5OmfNl1VM0
# 96               7          2019  4yugZvBYaoREkJKtbG08Qr
# 97              15          2019  0Xek5rqai2jcOWCYWJfVCF
# 98               1          2019  200x8ONbPfFzByUr3fVz46
# 99               4          2019  4tvBoSWeIW0bjhKNre5mod
#
# [100 rows x 10 columns]
