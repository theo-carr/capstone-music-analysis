# %% [markdown]
# # Test Spotify API import

# %%
import spotifyAPI as spot
# Out:
# Done

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import time

# %%
test = spot.new_release_features(limit = 2)

# %%
test
# Out:
# [{'danceability': 0.364,
#   'energy': 0.62,
#   'key': 5,
#   'loudness': -6.638,
#   'mode': 0,
#   'speechiness': 0.0555,
#   'acousticness': 0.736,
#   'instrumentalness': 0.00225,
#   'liveness': 0.429,
#   'valence': 0.491,
#   'tempo': 79.904,
#   'type': 'audio_features',
#   'id': '0YFqKxV9uNu6LUeYkLOKRS',
#   'uri': 'spotify:track:0YFqKxV9uNu6LUeYkLOKRS',
#   'track_href': 'https://api.spotify.com/v1/tracks/0YFqKxV9uNu6LUeYkLOKRS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0YFqKxV9uNu6LUeYkLOKRS',
#   'duration_ms': 168920,
#   'time_signature': 4},
#  {'danceability': 0.526,
#   'energy': 0.606,
#   'key': 5,
#   'loudness': -5.3,
#   'mode': 0,
#   'speechiness': 0.259,
#   'acousticness': 0.152,
#   'instrumentalness': 2.36e-06,
#   'liveness': 0.194,
#   'valence': 0.492,
#   'tempo': 116.622,
#   'type': 'audio_features',
#   'id': '0vjeOZ3Ft5jvAi9SBFJm1j',
#   'uri': 'spotify:track:0vjeOZ3Ft5jvAi9SBFJm1j',
# ...

# %%
print(len(test))
# Out:
# 229

# %% [markdown]
# scrape top 100 songs info frome some website
# 1. feed it into search
# 2. feed that id into feature
# 3. add on to our dataframe
#
# can do this for different years and decades, see what you can find
