# %% [markdown]
# # ***DO NOT RUN THIS NOTEBOOK FROM TOP TO BOTTOM***
# > YOU MAY OVERWRITE IMPORTANT DATAFRAMES

# %% [markdown]
# # notebook is for combining different years audio features into one table

# %%
import pandas as pd

# %% [markdown]
# # Read in csvs

# %%
af_2021 = pd.read_csv('../spotify/data/audio_features_2021.csv')
af_2019_2013 = pd.read_csv('../spotify/data/af_2019_2013.csv')
af_2011_2007 = pd.read_csv('../spotify/data/af_2011-2007.csv')
af_2005_2001 = pd.read_csv('../spotify/data/af_2005-2001.csv')

# %%
main_df = pd.concat(
   [af_2021,
    af_2019_2013,
    af_2011_2007,
    af_2005_2001]
)

# %%
main_df.head(3)

# %%
main_df.tail(3)

# %%
#main_df.to_csv('../spotify/data/af_2021_2001', index=False)

# %% [markdown]
# # ADD IN THE 90S!

# %%
# READ IN 90S AUDIO FEATURES (AF)
af_1999_1992 = pd.read_csv('../data/af_1999-1992.csv')

# %%
af_1999_1992
# Out:
#      danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0           0.853  0.9810   8.0    -3.947   1.0       0.0751       0.24700
# 1           0.661  0.3460  11.0    -9.115   1.0       0.0300       0.45200
# 2           0.590  0.6660   4.0    -4.047   0.0       0.0244       0.15600
# 3           0.610  0.4970   9.0    -9.880   1.0       0.0279       0.32000
# 4           0.826  0.6120   1.0    -3.891   1.0       0.0982       0.00681
# ..            ...     ...   ...       ...   ...          ...           ...
# 275         0.543  0.8730   9.0    -8.951   1.0       0.0324       0.01940
# 276         0.884  0.3700   8.0   -11.353   1.0       0.1120       0.01880
# 277         0.545  0.4850   9.0    -8.045   1.0       0.0485       0.53700
# 278         0.456  0.6950   6.0    -9.279   1.0       0.0496       0.08440
# 279         0.700  0.0657   4.0   -20.871   0.0       0.0308       0.95400
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.468000    0.3060   0.5950  118.193  audio_features
# 1            0.000000    0.1310   0.2560  129.752  audio_features
# 2            0.000000    0.1360   0.0743  104.042  audio_features
# 3            0.000061    0.0884   0.7390   85.031  audio_features
# 4            0.000000    0.0889   0.7560  120.057  audio_features
# ..                ...       ...      ...      ...             ...
# 275          0.000372    0.3240   0.9450  114.195  audio_features
# 276          0.004230    0.0260   0.8830  109.997  audio_features
# 277          0.000002    0.1040   0.1010   80.948  audio_features
# 278          0.000000    0.4990   0.3950  157.068  audio_features
# 279          0.932000    0.0941   0.1150   93.987  audio_features
#
#                          id                                   uri  \
# 0    2bCQHF9gdG5BNDVuEIEnNk  spotify:track:2bCQHF9gdG5BNDVuEIEnNk
# 1    6mwA6YiKDjAUG8kWvRRUPh  spotify:track:6mwA6YiKDjAUG8kWvRRUPh
# 2    5gZEhPrN1VLqTG1nIAXeNK  spotify:track:5gZEhPrN1VLqTG1nIAXeNK
# 3    6nozDLxeL0TE4MS9GqYU1v  spotify:track:6nozDLxeL0TE4MS9GqYU1v
# 4    6vc2Jq2vaGu8z326kSrw92  spotify:track:6vc2Jq2vaGu8z326kSrw92
# ..                      ...                                   ...
# 275  08FaxmURVgqiY9HDlW1wrh  spotify:track:08FaxmURVgqiY9HDlW1wrh
# 276  5DOYik1z3Of1wAFfY3dYbC  spotify:track:5DOYik1z3Of1wAFfY3dYbC
# 277  7woW97CfcWaKtuC6W5BP2K  spotify:track:7woW97CfcWaKtuC6W5BP2K
# 278  2QV1ZCi6q3QGp5PCqOqePg  spotify:track:2QV1ZCi6q3QGp5PCqOqePg
# 279  78JuhPiEBhlNe9c2tvbrIg  spotify:track:78JuhPiEBhlNe9c2tvbrIg
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/2bCQHF9gdG5B...
# 1    https://api.spotify.com/v1/tracks/6mwA6YiKDjAU...
# 2    https://api.spotify.com/v1/tracks/5gZEhPrN1VLq...
# 3    https://api.spotify.com/v1/tracks/6nozDLxeL0TE...
# 4    https://api.spotify.com/v1/tracks/6vc2Jq2vaGu8...
# ..                                                 ...
# 275  https://api.spotify.com/v1/tracks/08FaxmURVgqi...
# 276  https://api.spotify.com/v1/tracks/5DOYik1z3Of1...
# 277  https://api.spotify.com/v1/tracks/7woW97CfcWaK...
# 278  https://api.spotify.com/v1/tracks/2QV1ZCi6q3QG...
# 279  https://api.spotify.com/v1/tracks/78JuhPiEBhlN...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/2bCQ...     257760.0
# 1    https://api.spotify.com/v1/audio-analysis/6mwA...     263667.0
# 2    https://api.spotify.com/v1/audio-analysis/5gZE...     263800.0
# 3    https://api.spotify.com/v1/audio-analysis/6noz...     250360.0
# 4    https://api.spotify.com/v1/audio-analysis/6vc2...     187133.0
# ..                                                 ...          ...
# 275  https://api.spotify.com/v1/audio-analysis/08Fa...     264000.0
# 276  https://api.spotify.com/v1/audio-analysis/5DOY...     247507.0
# 277  https://api.spotify.com/v1/audio-analysis/7woW...     384307.0
# 278  https://api.spotify.com/v1/audio-analysis/2QV1...     308440.0
# 279  https://api.spotify.com/v1/audio-analysis/78Ju...     126396.0
#
#      time_signature  error
# 0               4.0    NaN
# 1               4.0    NaN
# 2               4.0    NaN
# 3               4.0    NaN
# 4               4.0    NaN
# ..              ...    ...
# 275             4.0    NaN
# 276             4.0    NaN
# 277             4.0    NaN
# 278             3.0    NaN
# 279             4.0    NaN
#
# [280 rows x 19 columns]

# %%
# load in current main df (2021-2001)
main_df = pd.read_csv('../data/af_2021_2001.csv')

# %%
main_df
# Out:
#       Unnamed: 0  danceability  energy   key  loudness  mode  speechiness  \
# 0            0.0         0.604   0.366   5.0    -7.519   1.0       0.0282
# 1            1.0         0.591   0.764   1.0    -5.484   1.0       0.0483
# 2            2.0         0.736   0.704   3.0    -7.409   0.0       0.0615
# 3            3.0         0.647   0.765   1.0    -6.459   1.0       0.0600
# 4            4.0         0.807   0.893  11.0    -3.745   0.0       0.0347
# ...          ...           ...     ...   ...       ...   ...          ...
# 1419         NaN         0.786   0.624   1.0    -6.096   1.0       0.2650
# 1420         NaN         0.612   0.799  10.0    -4.603   1.0       0.0275
# 1421         NaN         0.628   0.934  11.0    -6.026   1.0       0.0527
# 1422         NaN         0.299   0.422   5.0    -9.977   1.0       0.0285
# 1423         NaN         0.723   0.833   7.0    -4.879   1.0       0.1500
#
#       acousticness  instrumentalness  liveness  valence    tempo  \
# 0          0.57800          0.000000    0.1330    0.130  141.981
# 1          0.03830          0.000000    0.1030    0.478  169.928
# 2          0.02030          0.000000    0.0501    0.894  149.995
# 3          0.11100          0.000000    0.3150    0.855   79.994
# 4          0.04510          0.000028    0.3660    0.537  126.011
# ...            ...               ...       ...      ...      ...
# 1419       0.01680          0.000000    0.1060    0.657  100.868
# 1420       0.00898          0.000000    0.1720    0.687  125.976
# 1421       0.00682          0.000011    0.0852    0.491  126.538
# 1422       0.08730          0.000000    0.1820    0.168   67.797
# 1423       0.12300          0.000000    0.2720    0.616   82.741
#
#                 type                      id  \
# 0     audio_features  0gplL1WMoJ6iYaPgMCL0gX
# 1     audio_features  5HCyWlXZPP0y6Gqq8TgA20
# 2     audio_features  27NovPIUIRrOZoCHxABJwK
# 3     audio_features  58UKC45GPNTflCN6nwCUeF
# 4     audio_features  3rmo8F54jFF8OgYsqTxm5d
# ...              ...                     ...
# 1419  audio_features  1LTAztvz5NpyAwbGlVZTDr
# 1420  audio_features  7zVCrzzEJU7u24sbJPXA5W
# 1421  audio_features  5B6Z7NwVqA7W3UFiqBdEJC
# 1422  audio_features  623lYBOJ7bLwh1bu3yeN5V
# 1423  audio_features  1RbnH7qjUyWJWh8kjFIYNw
#
#                                        uri  duration_ms  time_signature  \
# 0     spotify:track:0gplL1WMoJ6iYaPgMCL0gX     224695.0             4.0
# 1     spotify:track:5HCyWlXZPP0y6Gqq8TgA20     141806.0             4.0
# 2     spotify:track:27NovPIUIRrOZoCHxABJwK     212000.0             4.0
# 3     spotify:track:58UKC45GPNTflCN6nwCUeF     161853.0             4.0
# 4     spotify:track:3rmo8F54jFF8OgYsqTxm5d     230747.0             4.0
# ...                                    ...          ...             ...
# 1419  spotify:track:1LTAztvz5NpyAwbGlVZTDr     267333.0             4.0
# 1420  spotify:track:7zVCrzzEJU7u24sbJPXA5W     188253.0             4.0
# 1421  spotify:track:5B6Z7NwVqA7W3UFiqBdEJC     265893.0             4.0
# 1422  spotify:track:623lYBOJ7bLwh1bu3yeN5V     191600.0             4.0
# 1423  spotify:track:1RbnH7qjUyWJWh8kjFIYNw     287867.0             4.0
#
#       error                                         track_href  \
# 0       NaN                                                NaN
# 1       NaN                                                NaN
# 2       NaN                                                NaN
# 3       NaN                                                NaN
# 4       NaN                                                NaN
# ...     ...                                                ...
# 1419    NaN  https://api.spotify.com/v1/tracks/1LTAztvz5Npy...
# 1420    NaN  https://api.spotify.com/v1/tracks/7zVCrzzEJU7u...
# 1421    NaN  https://api.spotify.com/v1/tracks/5B6Z7NwVqA7W...
# 1422    NaN  https://api.spotify.com/v1/tracks/623lYBOJ7bLw...
# 1423    NaN  https://api.spotify.com/v1/tracks/1RbnH7qjUyWJ...
#
#                                            analysis_url
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1419  https://api.spotify.com/v1/audio-analysis/1LTA...
# 1420  https://api.spotify.com/v1/audio-analysis/7zVC...
# 1421  https://api.spotify.com/v1/audio-analysis/5B6Z...
# 1422  https://api.spotify.com/v1/audio-analysis/623l...
# 1423  https://api.spotify.com/v1/audio-analysis/1Rbn...
#
# [1424 rows x 20 columns]

# %%
#overwrite main with 90s on bottom
main_df = pd.concat([main_df, af_1999_1992])

# %%
main_df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
main_df.reset_index(drop=True, inplace=True)

# %%
main_df
# Out:
#       danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0            0.604  0.3660   5.0    -7.519   1.0       0.0282        0.5780
# 1            0.591  0.7640   1.0    -5.484   1.0       0.0483        0.0383
# 2            0.736  0.7040   3.0    -7.409   0.0       0.0615        0.0203
# 3            0.647  0.7650   1.0    -6.459   1.0       0.0600        0.1110
# 4            0.807  0.8930  11.0    -3.745   0.0       0.0347        0.0451
# ...            ...     ...   ...       ...   ...          ...           ...
# 1699         0.543  0.8730   9.0    -8.951   1.0       0.0324        0.0194
# 1700         0.884  0.3700   8.0   -11.353   1.0       0.1120        0.0188
# 1701         0.545  0.4850   9.0    -8.045   1.0       0.0485        0.5370
# 1702         0.456  0.6950   6.0    -9.279   1.0       0.0496        0.0844
# 1703         0.700  0.0657   4.0   -20.871   0.0       0.0308        0.9540
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.1330    0.130  141.981  audio_features
# 1             0.000000    0.1030    0.478  169.928  audio_features
# 2             0.000000    0.0501    0.894  149.995  audio_features
# 3             0.000000    0.3150    0.855   79.994  audio_features
# 4             0.000028    0.3660    0.537  126.011  audio_features
# ...                ...       ...      ...      ...             ...
# 1699          0.000372    0.3240    0.945  114.195  audio_features
# 1700          0.004230    0.0260    0.883  109.997  audio_features
# 1701          0.000002    0.1040    0.101   80.948  audio_features
# 1702          0.000000    0.4990    0.395  157.068  audio_features
# 1703          0.932000    0.0941    0.115   93.987  audio_features
#
#                           id                                   uri  \
# 0     0gplL1WMoJ6iYaPgMCL0gX  spotify:track:0gplL1WMoJ6iYaPgMCL0gX
# 1     5HCyWlXZPP0y6Gqq8TgA20  spotify:track:5HCyWlXZPP0y6Gqq8TgA20
# 2     27NovPIUIRrOZoCHxABJwK  spotify:track:27NovPIUIRrOZoCHxABJwK
# 3     58UKC45GPNTflCN6nwCUeF  spotify:track:58UKC45GPNTflCN6nwCUeF
# 4     3rmo8F54jFF8OgYsqTxm5d  spotify:track:3rmo8F54jFF8OgYsqTxm5d
# ...                      ...                                   ...
# 1699  08FaxmURVgqiY9HDlW1wrh  spotify:track:08FaxmURVgqiY9HDlW1wrh
# 1700  5DOYik1z3Of1wAFfY3dYbC  spotify:track:5DOYik1z3Of1wAFfY3dYbC
# 1701  7woW97CfcWaKtuC6W5BP2K  spotify:track:7woW97CfcWaKtuC6W5BP2K
# 1702  2QV1ZCi6q3QGp5PCqOqePg  spotify:track:2QV1ZCi6q3QGp5PCqOqePg
# 1703  78JuhPiEBhlNe9c2tvbrIg  spotify:track:78JuhPiEBhlNe9c2tvbrIg
#
#       duration_ms  time_signature  error  \
# 0        224695.0             4.0    NaN
# 1        141806.0             4.0    NaN
# 2        212000.0             4.0    NaN
# 3        161853.0             4.0    NaN
# 4        230747.0             4.0    NaN
# ...           ...             ...    ...
# 1699     264000.0             4.0    NaN
# 1700     247507.0             4.0    NaN
# 1701     384307.0             4.0    NaN
# 1702     308440.0             3.0    NaN
# 1703     126396.0             4.0    NaN
#
#                                              track_href  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1699  https://api.spotify.com/v1/tracks/08FaxmURVgqi...
# 1700  https://api.spotify.com/v1/tracks/5DOYik1z3Of1...
# 1701  https://api.spotify.com/v1/tracks/7woW97CfcWaK...
# 1702  https://api.spotify.com/v1/tracks/2QV1ZCi6q3QG...
# 1703  https://api.spotify.com/v1/tracks/78JuhPiEBhlN...
#
#                                            analysis_url
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1699  https://api.spotify.com/v1/audio-analysis/08Fa...
# 1700  https://api.spotify.com/v1/audio-analysis/5DOY...
# 1701  https://api.spotify.com/v1/audio-analysis/7woW...
# 1702  https://api.spotify.com/v1/audio-analysis/2QV1...
# 1703  https://api.spotify.com/v1/audio-analysis/78Ju...
#
# [1704 rows x 19 columns]

# %%
#save main back to data comment out when done and don't forget to set idnex to false
#main_df.to_csv('../data/af_2021_1992.csv')
